# %%
import matplotlib.pyplot as plt
from pyro.distributions import Weibull

# %%
m = Weibull(scale=8, concentration=2)
samples = m.sample((10000,))

plt.hist(samples.numpy(), bins=50, density=True)
plt.xlim(0, None)
plt.ylabel("density  - Weibull(x)")
pass
